# %%
# !pip install munkres
# Out:
# Requirement already satisfied: munkres in /usr/local/lib/python3.11/dist-packages (1.1.4)

# %%
# !pip install tensorflow==2.12.0rc0
# Out:
# Requirement already satisfied: tensorflow==2.12.0rc0 in /usr/local/lib/python3.11/dist-packages (2.12.0rc0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.71.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (3.13.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0rc0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0rc0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (1.17.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0rc0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0rc0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0rc0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0rc0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0rc0) (1.14.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0rc0) (3.2.2)

# %%
# !git clone https://github.com/hira-husnain/SADSE
# Out:
# fatal: destination path 'SADSE' already exists and is not an empty directory.

# %%
cd SADSE
# Out:
# /content/SADSE

# %%
import numpy as np
x_train=np.load('./datasets/ORL/d_orl.npy')
x_train=x_train.reshape(x_train.shape[0]*x_train.shape[1],400)
y=np.load('./datasets/ORL/l_orl.npy')
y=y.reshape(y.shape[0]*y.shape[1],)
alpha_trans1=np.load('./datasets/ORL/Sb_orl.npy',allow_pickle=True)
alpha_trans1=np.asarray(alpha_trans1).astype('float32')
import glob
import numpy as np
import random
import tensorflow.compat.v1 as tf
import os

batchSize=400
from sklearn.metrics.pairwise import euclidean_distances
from scipy.linalg import fractional_matrix_power
from scipy import linalg
import sklearn
from sklearn.cluster import KMeans
from tensorflow.keras import backend as B
k_cluster = 40
from tensorflow.keras.layers import Input,Dense,Lambda,Layer
from tensorflow.keras.models import Model
import sys
import numpy as np
from scipy.io import loadmat
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from munkres import Munkres
import cv2
from numpy import save


def make_cost_matrix(c1, c2):
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    for a in range (1):
        if uc1.shape==uc2.shape:
            m = np.ones([l1, l2])
            for i in range(l1):
                it_i = np.nonzero(c1 == uc1[i])[0]
                for j in range(l2):
                    it_j = np.nonzero(c2 == uc2[j])[0]
                    m_ij = np.intersect1d(it_j, it_i)
                    m[i,j] =  -m_ij.size
        else:
            print('assertion handeled')
            return
            #break
    return m

def translate_clustering(clt, mapper):
    return np.array([ mapper[i] for i in clt ])

def accuracy(cm):
    return np.trace(cm, dtype=float) / np.sum(cm)

def rectify_label(labels, classes):
    num_labels = len(np.unique(classes))
    cm = confusion_matrix(classes, labels, labels=range(num_labels)) # gets the confusion matrix
    cost_matrix = make_cost_matrix(labels, classes)
    if cost_matrix is None:
        return (None,None)
    else:
        m = Munkres()
        indexes = m.compute(cost_matrix)
        mapper = { old: new for (old, new) in indexes }
        new_labels = translate_clustering(labels, mapper)
        new_cm = confusion_matrix(classes, new_labels, labels=range(num_labels))
        return new_labels,accuracy(new_cm)

def arch():
    encoding_dim = 390  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats
    input_img = Input(shape=(400,))
    encoded_layer_2 = Dense(397, activation='tanh')(input_img)
    encoded_layer_3 = Dense(395, activation='tanh')(encoded_layer_2)
    encoded_layer_4 = Dense(393, activation='tanh')(encoded_layer_3)
    encoded = Dense(encoding_dim, activation='tanh')(encoded_layer_4)
    decoded_layer_2 = Dense(393, activation='tanh')(encoded)
    decoded_layer_3 = Dense(395, activation='tanh')(decoded_layer_2)
    decoded_layer_4 = Dense(397, activation='tanh')(decoded_layer_3)
    decoded = Dense(400, activation='tanh')(decoded_layer_4)
    encoder=Model(input_img,encoded)
    autoencoder=Model(input_img,decoded)
    return encoder,encoding_dim,autoencoder



def assign_func(z_test,z_ic):
    dst = np.array(np.sum(((z_test-z_ic[0]) **2),axis=1))
    for index in range(1, z_ic.shape[0]):
        col = np.sum(((z_test- z_ic[index])**2), axis=1)
        dst = np.vstack((dst, col))
    dst = dst.T

    mean_dst = np.mean(dst, axis=1)
    q = np.maximum(0.0, np.tile(mean_dst, (dst.shape[1], 1)).T - dst)
    #print(q.shape)
    num_centers = q.shape[1]
    weight = 1.0 / (q.sum(axis=0) + 1e-9)
    weight *= num_centers / weight.sum()
    q = (q ** 2.0) * weight
    q = (q.T / (q.sum(axis=1) + B.epsilon())).T
    return q

def asl():
    def myloss(y_true, y_pred):
        l1norm= l1norm_func(y_pred,y_true)
        l2norm= l2norm_func(y_pred,y_true)
        orthonormal= orthonormality_func(y_pred)
        structpreserve=structurePreserve_func(y_pred,alpha_trans1[g][:,:])
        return orthonormal+l1norm+l2norm+structpreserve
    return myloss

def l1norm_func(z,nt):
    q1=0.002*(tf.reduce_sum(tf.abs(tf.subtract(z,nt)),axis=1))
    return q1

def l2norm_func(z,nt):
    q2=0.02*(tf.sqrt(tf.reduce_sum(tf.square(z-nt),axis=1)))
    return q2

def structurePreserve_func(z,ta):
    tz=tf.transpose(z)
    tz=tf.reshape(tz,(encoding_dim,batchSize))
    taa=tf.transpose(ta)
    taz=tf.matmul(tz,taa)
    taz=tf.reshape(taz,(encoding_dim,batchSize))
    q4=0.02*(tf.sqrt(tf.reduce_sum(tf.square(tz-taz))))
    q4=tf.transpose(q4)
    return q4


def orthonormality_func(z):
    z=[(z[i,:]/(tf.norm(z[i,:],2)))for i in range (batchSize)]
    transz=tf.transpose(z)
    q3=tf.tensordot(transz,z,axes=1)
    I=tf.eye(encoding_dim)
    q5=0.002*(tf.sqrt(tf.reduce_sum(tf.square(q3-I))))
    return q5
encoder,encoding_dim,autoencoder=arch()
print('loading pre trained model')
encoder.load_weights('./checkpoints/chk_orl/sdsc_orl.ckpt')
z_test=encoder.predict(x_train)
ic= np.load('./checkpoints/chk_orl/sdsc_icorl.npy')
assignment = assign_func(z_test, ic)
predictedlabels = np.argmax(assignment, axis=1)
rectified_label, acc=rectify_label(predictedlabels, y)
nmi=sklearn.metrics.normalized_mutual_info_score(y, rectified_label)
f1=sklearn.metrics.f1_score(y, rectified_label,average='micro')
prec=sklearn.metrics.precision_score(y, rectified_label,average='weighted')
print(acc,nmi,f1,prec)
# Out:
# loading pre trained model
# 13/13 [==============================] - 0s 5ms/step
# 0.9075 0.9466350858615871 0.9075 0.9261012598512598

# %% [markdown]
# #training from scratch

# %%
import glob
import numpy as np
import random
import tensorflow.compat.v1 as tf
import os
from sklearn.utils import shuffle
batchSize=400
from sklearn.metrics.pairwise import euclidean_distances
from scipy.linalg import fractional_matrix_power
from scipy import linalg
import sklearn
from sklearn.cluster import KMeans
from tensorflow.keras import backend as B
k_cluster = 40
from tensorflow.keras.layers import Input,Dense,Lambda,Layer
dnet=tf.keras.applications.densenet.DenseNet121(include_top=False,weights="imagenet",input_tensor=None,input_shape=None,pooling=None)
from tensorflow.keras.models import Model
import sys
import numpy as np
from scipy.io import loadmat
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from munkres import Munkres
import cv2
from numpy import save


def load_data():
    train_set = []
    y= []
    #dim=(48,48)
    counter_i = 0
    for filename in glob.iglob('./datasets/ORL/orl-dataset/*/*.pgm'):
        img = cv2.imread(filename, -1)
        #img=cv2.resize(img,dim,interpolation=cv2.INTER_LINEAR)
        train_set.append(img)
        parts=os.path.split(filename)[0]
        parts=parts.split('/')[10]
        parts=parts.split('s')[1]
        y.append(parts)
        print(counter_i)
        counter_i += 1
    y=np.int32(y)
    y=y-1
    train_set, y = shuffle(train_set, y, random_state=42)
    return train_set,y

def extract_features(vtr):
    for i in range(len(vtr)):
        vtr[i]=vtr[i]/np.linalg.norm(vtr[i],2)
    pca.fit(vtr)
    x=pca.transform(vtr)
    return x

def eig_vec(x_train):
    nev_trans=[]
    SortedEigVec=np.zeros((batchSize,batchSize))
    for l in range (0,len(x_train),batchSize):
        xtr=x_train[l:l+batchSize]
        d=(euclidean_distances(xtr,xtr))
        W=np.zeros((len(xtr),len(xtr)))
        for i in range(len(xtr)):
            for j in range (len(xtr)):
                if i==j:
                    W[i,j]=0
                else:
                    W[i,j]=np.exp(-(d[i,j]**2)/(2*0.09))
        degree=np.diag(sum(W))
        L = degree-W
        eig_val,eig_vec=np.linalg.eig(L)
        dec_eigVal=np.flip(np.sort(eig_val))
        indexArr=(np.flip(np.argsort(eig_val)))
        for i in range (len(indexArr)):
            SortedEigVec[:,i]=eig_vec[:,indexArr[i]]
        SortedEigVec=np.array(SortedEigVec)
        nev_trans.append(SortedEigVec)
    return nev_trans,L,eig_val,eig_vec,dec_eigVal,W

def make_cost_matrix(c1, c2):
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    for a in range (1):
        if uc1.shape==uc2.shape:
            m = np.ones([l1, l2])
            for i in range(l1):
                it_i = np.nonzero(c1 == uc1[i])[0]
                for j in range(l2):
                    it_j = np.nonzero(c2 == uc2[j])[0]
                    m_ij = np.intersect1d(it_j, it_i)
                    m[i,j] =  -m_ij.size
        else:
            print('assertion handeled')
            return
            #break
    return m

def translate_clustering(clt, mapper):
    return np.array([ mapper[i] for i in clt ])

def accuracy(cm):
    return np.trace(cm, dtype=float) / np.sum(cm)

def rectify_label(labels, classes):
    num_labels = len(np.unique(classes))
    cm = confusion_matrix(classes, labels, labels=range(num_labels)) # gets the confusion matrix
    cost_matrix = make_cost_matrix(labels, classes)
    if cost_matrix is None:
        return (None,None)
    else:
        m = Munkres()
        indexes = m.compute(cost_matrix)
        mapper = { old: new for (old, new) in indexes }
        new_labels = translate_clustering(labels, mapper)
        new_cm = confusion_matrix(classes, new_labels, labels=range(num_labels))
        return new_labels,accuracy(new_cm)

def arch():
    encoding_dim = 390  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats
    input_img = Input(shape=(400,))
    encoded_layer_2 = Dense(397, activation='tanh')(input_img)
    encoded_layer_3 = Dense(395, activation='tanh')(encoded_layer_2)
    encoded_layer_4 = Dense(393, activation='tanh')(encoded_layer_3)
    encoded = Dense(encoding_dim, activation='tanh')(encoded_layer_4)
    decoded_layer_2 = Dense(393, activation='tanh')(encoded)
    decoded_layer_3 = Dense(395, activation='tanh')(decoded_layer_2)
    decoded_layer_4 = Dense(397, activation='tanh')(decoded_layer_3)
    decoded = Dense(400, activation='tanh')(decoded_layer_4)
    encoder=Model(input_img,encoded)
    autoencoder=Model(input_img,decoded)
    return encoder,encoding_dim,autoencoder


def assign_func(z_test,z_ic):
    dst = np.array(np.sum(((z_test-z_ic[0]) **2),axis=1))
    for index in range(1, z_ic.shape[0]):
        col = np.sum(((z_test- z_ic[index])**2), axis=1)
        dst = np.vstack((dst, col))
    dst = dst.T

    mean_dst = np.mean(dst, axis=1)
    q = np.maximum(0.0, np.tile(mean_dst, (dst.shape[1], 1)).T - dst)
    #print(q.shape)
    num_centers = q.shape[1]
    weight = 1.0 / (q.sum(axis=0) + 1e-9)
    weight *= num_centers / weight.sum()
    q = (q ** 2.0) * weight
    q = (q.T / (q.sum(axis=1) + B.epsilon())).T
    return q

def asl():
    def myloss(y_true, y_pred):
        l1norm= l1norm_func(y_pred,y_true)
        l2norm= l2norm_func(y_pred,y_true)
        orthonormal= orthonormality_func(y_pred)
        structpreserve=structurePreserve_func(y_pred,alpha_trans1[g][:,:])
        return orthonormal+l1norm+l2norm+structpreserve
    return myloss

def l1norm_func(z,nt):
    q1=0.002*(tf.reduce_sum(tf.abs(tf.subtract(z,nt)),axis=1))
    return q1

def l2norm_func(z,nt):
    q2=0.02*(tf.sqrt(tf.reduce_sum(tf.square(z-nt),axis=1)))
    return q2

def structurePreserve_func(z,ta):
    tz=tf.transpose(z)
    tz=tf.reshape(tz,(encoding_dim,batchSize))
    taa=tf.transpose(ta)
    taz=tf.matmul(tz,taa)
    taz=tf.reshape(taz,(encoding_dim,batchSize))
    q4=0.02*(tf.sqrt(tf.reduce_sum(tf.square(tz-taz))))
    q4=tf.transpose(q4)
    return q4


def orthonormality_func(z):
    z=[(z[i,:]/(tf.norm(z[i,:],2)))for i in range (batchSize)]
    transz=tf.transpose(z)
    q3=tf.tensordot(transz,z,axes=1)
    I=tf.eye(encoding_dim)
    q5=0.002*(tf.sqrt(tf.reduce_sum(tf.square(q3-I))))
    return q5

#train_set,y1=load_data()
#train_set=np.array(train_set)
#y1=np.array(y1)
#train_set=np.stack((train_set,)*3, axis=-1)
#train_set = train_set.astype('float32') / 255.
#vtr=dnet.predict(train_set)
#vtr = vtr.reshape((len(vtr), np.prod(vtr.shape[1:])))
#x,y=extract_features(vtr,y)
#x_train=x
#y=y1
print(x_train.shape,y.shape)
# np.save('orldataforSb.npy',x_train)
# np.save('orllabelsforSb,y)
nev_trans,L,eig_val,eig_vec,dec_eigVal,W=eig_vec(x_train)
alpha_trans1=np.load('./datasets/ORL/Sb_orl.npy',allow_pickle=True)
alpha_trans1=np.asarray(alpha_trans1).astype('float32')
encoder,encoding_dim,autoencoder=arch()
autoencoder.compile(tf.keras.optimizers.Adam(lr=1e-3), loss=tf.keras.losses.MeanSquaredError())
autoencoder.fit(x_train,x_train,epochs=100,shuffle=True,batch_size=batchSize)
encoder.save_weights('./new_checkpoints/nchk_orl/nE_orl.ckpt')

print('training from scratch')
encoder.load_weights('./new_checkpoints/nchk_orl/nE_orl.ckpt')
g=0
encoder.compile(tf.keras.optimizers.Adadelta(lr=1e-3, rho=0.95, decay=1e-4), loss=asl())

acc=0
for t in range (1,4000,1):
    g=0
    for l in range (0,len(x_train),batchSize):
        encoder.fit(x_train[l:l+batchSize],nev_trans[g][:,batchSize-encoding_dim-1:batchSize-1],epochs=1,shuffle=False,batch_size=batchSize)
        g=g+1
    z_test=encoder.predict(x_train)
    k_means = KMeans(n_clusters=k_cluster, init='k-means++')
    ic= k_means.fit(z_test).cluster_centers_
    assignment = assign_func(z_test, ic)
    predictedlabels = np.argmax(assignment, axis=1)
    rectified_label, num=rectify_label(predictedlabels, y)
    if rectified_label is not None:
        print('acc at',t, 'epoch is:',acc)
        if acc<num:
            acc=num
            encoder.save_weights('./new_checkpoints/nchk_orl/nsdsc_orl.ckpt')
            np.save('./new_checkpoints/nchk_orl/nsdsc_icorl.npy',ic)
            nmi=sklearn.metrics.normalized_mutual_info_score(y, rectified_label)
            f1=sklearn.metrics.f1_score(y, rectified_label,average='micro')
            prec=sklearn.metrics.precision_score(y, rectified_label,average='weighted')
    else:
        continue
print(acc,nmi,f1,prec)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# (400, 400) (400,)
# /usr/local/lib/python3.11/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0049
# Epoch 2/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0036
# Epoch 3/100
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0029
# Epoch 4/100
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0025
# Epoch 5/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0023
# Epoch 6/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0021
# Epoch 7/100
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0019
# Epoch 8/100
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0018
# Epoch 9/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0017
# Epoch 10/100
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0016
# Epoch 11/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0015
# Epoch 12/100
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0014
# Epoch 13/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0013
# Epoch 14/100
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0012
# Epoch 15/100
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0012
# Epoch 16/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0011
# Epoch 17/100
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0011
# Epoch 18/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0010
# Epoch 19/100
# 1/1 [==============================] - 0s 161ms/step - loss: 9.8853e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 121ms/step - loss: 9.4994e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 119ms/step - loss: 9.1373e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 188ms/step - loss: 8.8009e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 243ms/step - loss: 8.4907e-04
# Epoch 24/100
# 1/1 [==============================] - 0s 147ms/step - loss: 8.2064e-04
# Epoch 25/100
# 1/1 [==============================] - 0s 160ms/step - loss: 7.9490e-04
# Epoch 26/100
# 1/1 [==============================] - 0s 209ms/step - loss: 7.7139e-04
# Epoch 27/100
# 1/1 [==============================] - 0s 151ms/step - loss: 7.4921e-04
# Epoch 28/100
# 1/1 [==============================] - 0s 141ms/step - loss: 7.2790e-04
# Epoch 29/100
# 1/1 [==============================] - 0s 144ms/step - loss: 7.0769e-04
# Epoch 30/100
# 1/1 [==============================] - 0s 170ms/step - loss: 6.8880e-04
epoch is: 0.9025
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6626
# 13/13 [==============================] - 0s 5ms/step
# acc at 2352 epoch is: 0.9025
# 1/1 [==============================] - 0s 216ms/step - loss: 0.6626
# 13/13 [==============================] - 0s 5ms/step
# acc at 2353 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6625
# 13/13 [==============================] - 0s 5ms/step
# acc at 2354 epoch is: 0.9025
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6624
# 13/13 [==============================] - 0s 5ms/step
# acc at 2355 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6624
# 13/13 [==============================] - 0s 6ms/step
# acc at 2356 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6623
# 13/13 [==============================] - 0s 4ms/step
# acc at 2357 epoch is: 0.9025
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6623
# 13/13 [==============================] - 0s 4ms/step
# acc at 2358 epoch is: 0.9025
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6622
# 13/13 [==============================] - 0s 5ms/step
# acc at 2359 epoch is: 0.9025
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6622
# 13/13 [==============================] - 0s 4ms/step
# acc at 2360 epoch is: 0.9025
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6621
# 13/13 [==============================] - 0s 8ms/step
# acc at 2361 epoch is: 0.9025
# 1/1 [==============================] - 0s 280ms/step - loss: 0.6621
# 13/13 [==============================] - 0s 6ms/step
# acc at 2362 epoch is: 0.9025
# 1/1 [==============================] - 1s 504ms/step - loss: 0.6620
# 13/13 [==============================] - 0s 7ms/step
# acc at 2363 epoch is: 0.9025
# 1/1 [==============================] - 0s 312ms/step - loss: 0.6620
# 13/13 [==============================] - 0s 5ms/step
# acc at 2364 epoch is: 0.9025
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6619
# 13/13 [==============================] - 0s 4ms/step
# acc at 2365 epoch is: 0.9025
# 1/1 [==============================] - 0s 224ms/step - loss: 0.6619
# 13/13 [==============================] - 0s 5ms/step
# acc at 2366 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6618
# 13/13 [==============================] - 0s 4ms/step
# acc at 2367 epoch is: 0.9025
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6618
# 13/13 [==============================] - 0s 4ms/step
# acc at 2368 epoch is: 0.9025
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6617
# 13/13 [==============================] - 0s 5ms/step
# acc at 2369 epoch is: 0.9025
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6617
# 13/13 [==============================] - 0s 4ms/step
# acc at 2370 epoch is: 0.9025
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6616
# 13/13 [==============================] - 0s 5ms/step
# acc at 2371 epoch is: 0.9025
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6616
# 13/13 [==============================] - 0s 4ms/step
# acc at 2372 epoch is: 0.9025
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6615
# 13/13 [==============================] - 0s 5ms/step
# acc at 2373 epoch is: 0.9025
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6615
# 13/13 [==============================] - 0s 5ms/step
# acc at 2374 epoch is: 0.9025
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6614
# 13/13 [==============================] - 0s 5ms/step
# acc at 2375 epoch is: 0.9025
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6614
# 13/13 [==============================] - 0s 4ms/step
# acc at 2376 epoch is: 0.9025
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6613
# 13/13 [==============================] - 0s 5ms/step
# acc at 2377 epoch is: 0.9025
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6613
# 13/13 [==============================] - 0s 5ms/step
# acc at 2378 epoch is: 0.9025
# 1/1 [==============================] - 0s 229ms/step - loss: 0.6612
# 13/13 [==============================] - 0s 6ms/step
# acc at 2379 epoch is: 0.9025
# 1/1 [==============================] - 0s 341ms/step - loss: 0.6611
# 13/13 [==============================] - 0s 7ms/step
# acc at 2380 epoch is: 0.9025
# 1/1 [==============================] - 0s 326ms/step - loss: 0.6611
# 13/13 [==============================] - 0s 7ms/step
# acc at 2381 epoch is: 0.9025
# 1/1 [==============================] - 0s 216ms/step - loss: 0.6610
# 13/13 [==============================] - 0s 5ms/step
# acc at 2382 epoch is: 0.9025
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6610
# 13/13 [==============================] - 0s 4ms/step
# acc at 2383 epoch is: 0.9025
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6609
# 13/13 [==============================] - 0s 4ms/step
# acc at 2384 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6592
# 13/13 [==============================] - 0s 4ms/step
# acc at 2417 epoch is: 0.9025
# 1/1 [==============================] - 0s 184ms/step - loss: 0.6592
# 13/13 [==============================] - 0s 4ms/step
# acc at 2418 epoch is: 0.9025
# 1/1 [==============================] - 0s 183ms/step - loss: 0.6591
# 13/13 [==============================] - 0s 5ms/step
# acc at 2419 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6591
# 13/13 [==============================] - 0s 6ms/step
# acc at 2420 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6590
# 13/13 [==============================] - 0s 4ms/step
# acc at 2421 epoch is: 0.9025
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6590
# 13/13 [==============================] - 0s 4ms/step
# acc at 2422 epoch is: 0.9025
# 1/1 [==============================] - 0s 269ms/step - loss: 0.6589
# 13/13 [==============================] - 0s 4ms/step
# acc at 2423 epoch is: 0.9025
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6589
# 13/13 [==============================] - 0s 4ms/step
# acc at 2424 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6588
# 13/13 [==============================] - 0s 5ms/step
# acc at 2425 epoch is: 0.9025
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6588
# 13/13 [==============================] - 0s 5ms/step
# acc at 2426 epoch is: 0.9025
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6587
# 13/13 [==============================] - 0s 5ms/step
# acc at 2427 epoch is: 0.9025
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6587
# 13/13 [==============================] - 0s 4ms/step
# acc at 2428 epoch is: 0.9025
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6586
# 13/13 [==============================] - 0s 4ms/step
# acc at 2429 epoch is: 0.9025
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6586
# 13/13 [==============================] - 0s 4ms/step
# acc at 2430 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6585
# 13/13 [==============================] - 0s 4ms/step
# acc at 2431 epoch is: 0.9025
# 1/1 [==============================] - 0s 259ms/step - loss: 0.6585
# 13/13 [==============================] - 0s 5ms/step
# acc at 2432 epoch is: 0.9025
# 1/1 [==============================] - 0s 337ms/step - loss: 0.6584
# 13/13 [==============================] - 0s 7ms/step
# acc at 2433 epoch is: 0.9025
# 1/1 [==============================] - 0s 323ms/step - loss: 0.6584
# 13/13 [==============================] - 0s 6ms/step
# acc at 2434 epoch is: 0.9025
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6583
# 13/13 [==============================] - 0s 4ms/step
# acc at 2435 epoch is: 0.9025
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6583
# 13/13 [==============================] - 0s 5ms/step
# acc at 2436 epoch is: 0.9025
# 1/1 [==============================] - 0s 183ms/step - loss: 0.6582
# 13/13 [==============================] - 0s 5ms/step
# acc at 2437 epoch is: 0.9025
# 1/1 [==============================] - 0s 293ms/step - loss: 0.6582
# 13/13 [==============================] - 0s 5ms/step
# acc at 2438 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6581
# 13/13 [==============================] - 0s 4ms/step
# acc at 2439 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6581
# 13/13 [==============================] - 0s 4ms/step
# acc at 2440 epoch is: 0.9025
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6580
# 13/13 [==============================] - 0s 4ms/step
# acc at 2441 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6580
# 13/13 [==============================] - 0s 4ms/step
# acc at 2442 epoch is: 0.9025
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6579
# 13/13 [==============================] - 0s 5ms/step
# acc at 2443 epoch is: 0.9025
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6579
# 13/13 [==============================] - 0s 4ms/step
# acc at 2444 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6578
# 13/13 [==============================] - 0s 4ms/step
# acc at 2445 epoch is: 0.9025
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6578
# 13/13 [==============================] - 0s 5ms/step
# acc at 2446 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6577
# 13/13 [==============================] - 0s 4ms/step
# acc at 2447 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6577
# 13/13 [==============================] - 0s 5ms/step
# acc at 2448 epoch is: 0.9025
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6576
# 13/13 [==============================] - 0s 5ms/step
# acc at 2449 epoch is: 0.9025
# 1/1 [==============================] - 0s 222ms/step - loss: 0.
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6560
# 13/13 [==============================] - 0s 5ms/step
# acc at 2482 epoch is: 0.9025
# 1/1 [==============================] - 0s 282ms/step - loss: 0.6559
# 13/13 [==============================] - 0s 4ms/step
# acc at 2483 epoch is: 0.9025
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6559
# 13/13 [==============================] - 0s 4ms/step
# acc at 2484 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6558
# 13/13 [==============================] - 0s 6ms/step
# acc at 2485 epoch is: 0.9025
# 1/1 [==============================] - 0s 284ms/step - loss: 0.6558
# 13/13 [==============================] - 0s 4ms/step
# acc at 2486 epoch is: 0.9025
# 1/1 [==============================] - 0s 279ms/step - loss: 0.6557
# 13/13 [==============================] - 0s 5ms/step
# acc at 2487 epoch is: 0.9025
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6557
# 13/13 [==============================] - 0s 6ms/step
# acc at 2488 epoch is: 0.9025
# 1/1 [==============================] - 0s 181ms/step - loss: 0.6556
# 13/13 [==============================] - 0s 4ms/step
# acc at 2489 epoch is: 0.9025
# 1/1 [==============================] - 0s 163ms/step - loss: 0.6556
# 13/13 [==============================] - 0s 4ms/step
# acc at 2490 epoch is: 0.9025
# 1/1 [==============================] - 0s 157ms/step - loss: 0.6555
# 13/13 [==============================] - 0s 5ms/step
# acc at 2491 epoch is: 0.9025
# 1/1 [==============================] - 0s 165ms/step - loss: 0.6555
# 13/13 [==============================] - 0s 4ms/step
# acc at 2492 epoch is: 0.9025
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6554
# 13/13 [==============================] - 0s 4ms/step
# acc at 2493 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6554
# 13/13 [==============================] - 0s 4ms/step
# acc at 2494 epoch is: 0.9025
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6553
# 13/13 [==============================] - 0s 5ms/step
# acc at 2495 epoch is: 0.9025
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6553
# 13/13 [==============================] - 0s 4ms/step
# acc at 2496 epoch is: 0.9025
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6552
# 13/13 [==============================] - 0s 5ms/step
# acc at 2497 epoch is: 0.9025
# 1/1 [==============================] - 0s 281ms/step - loss: 0.6552
# 13/13 [==============================] - 0s 4ms/step
# acc at 2498 epoch is: 0.9025
# 1/1 [==============================] - 0s 215ms/step - loss: 0.6551
# 13/13 [==============================] - 0s 4ms/step
# acc at 2499 epoch is: 0.9025
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6551
# 13/13 [==============================] - 0s 6ms/step
# acc at 2500 epoch is: 0.9025
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6550
# 13/13 [==============================] - 0s 4ms/step
# acc at 2501 epoch is: 0.9025
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6550
# 13/13 [==============================] - 0s 5ms/step
# acc at 2502 epoch is: 0.9025
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6549
# 13/13 [==============================] - 0s 5ms/step
# acc at 2503 epoch is: 0.9025
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6549
# 13/13 [==============================] - 0s 4ms/step
# acc at 2504 epoch is: 0.9025
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6548
# 13/13 [==============================] - 0s 8ms/step
# acc at 2505 epoch is: 0.9025
# 1/1 [==============================] - 0s 339ms/step - loss: 0.6548
# 13/13 [==============================] - 0s 6ms/step
# acc at 2506 epoch is: 0.9025
# 1/1 [==============================] - 0s 334ms/step - loss: 0.6547
# 13/13 [==============================] - 0s 5ms/step
# acc at 2507 epoch is: 0.9025
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6547
# 13/13 [==============================] - 0s 5ms/step
# acc at 2508 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6546
# 13/13 [==============================] - 0s 4ms/step
# acc at 2509 epoch is: 0.9025
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6546
# 13/13 [==============================] - 0s 4ms/step
# acc at 2510 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6545
# 13/13 [==============================] - 0s 4ms/step
# acc at 2511 epoch is: 0.9025
# 1/1 [==============================] - 0s 215ms/step - loss: 0.6545
# 13/13 [==============================] - 0s 5ms/step
# acc at 2512 epoch is: 0.9025
# 1/1 [==============================] - 0s 265ms/step - loss: 0.6544
# 13/13 [==============================] - 0s 6ms/step
# acc at 2513 epoch is: 0.9025
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6544
# 13/13 [==============================] - 0s 5ms/step
# acc at 2514 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6543
# 13/13 [==============================] - 0s 4ms/step
# acc at 2515 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6543
# 13/13 [==============================] - 0s 4ms/step
# acc at 2516 epoch is: 0.9025
# 1/1 [==============================] - 0s 215ms/step - loss: 0.6542
# 13/13 [==============================] - 0s 4ms/step
# acc at 2517 epoch is: 0.9025
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6542
# 13/13 [==============================] - 0s 4ms/step
# acc at 2518 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6541
# 13/13 [==============================] - 0s 5ms/step
# acc at 2519 epoch is: 0.9025
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6541
# 13/13 [==============================] - 0s 4ms/step
# acc at 2520 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6540
# 13/13 [==============================] - 0s 4ms/step
# acc at 2521 epoch is: 0.9025
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6540
# 13/13 [==============================] - 0s 7ms/step
# acc at 2522 epoch is: 0.9025
# 1/1 [==============================] - 0s 311ms/step - loss: 0.6539
# 13/13 [==============================] - 0s 4ms/step
# acc at 2523 epoch is: 0.9025
# 1/1 [==============================] - 0s 318ms/step - loss: 0.6539
# 13/13 [==============================] - 0s 6ms/step
# acc at 2524 epoch is: 0.9025
# 1/1 [==============================] - 0s 363ms/step - loss: 0.6538
# 13/13 [==============================] - 0s 5ms/step
# acc at 2525 epoch is: 0.9025
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6538
# 13/13 [==============================] - 0s 5ms/step
# acc at 2526 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6537
# 13/13 [==============================] - 0s 7ms/step
# acc at 2527 epoch is: 0.9025
# 1/1 [==============================] - 0s 265ms/step - loss: 0.6537
# 13/13 [==============================] - 0s 5ms/step
# acc at 2528 epoch is: 0.9025
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6536
# 13/13 [==============================] - 0s 5ms/step
# acc at 2529 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6536
# 13/13 [==============================] - 0s 6ms/step
# acc at 2530 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6535
# 13/13 [==============================] - 0s 5ms/step
# acc at 2531 epoch is: 0.9025
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6535
# 13/13 [==============================] - 0s 4ms/step
# acc at 2532 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6534
# 13/13 [==============================] - 0s 4ms/step
# acc at 2533 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6534
# 13/13 [==============================] - 0s 4ms/step
# acc at 2534 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6533
# 13/13 [==============================] - 0s 6ms/step
# acc at 2535 epoch is: 0.9025
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6533
# 13/13 [==============================] - 0s 5ms/step
# acc at 2536 epoch is: 0.9025
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6532
# 13/13 [==============================] - 0s 4ms/step
# acc at 2537 epoch is: 0.9025
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6532
# 13/13 [==============================] - 0s 4ms/step
# acc at 2538 epoch is: 0.9025
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6531
# 13/13 [==============================] - 0s 4ms/step
# acc at 2539 epoch is: 0.9025
# 1/1 [==============================] - 0s 340ms/step - loss: 0.6531
# 13/13 [==============================] - 0s 5ms/step
# acc at 2540 epoch is: 0.9025
# 1/1 [==============================] - 0s 330ms/step - loss: 0.6530
# 13/13 [==============================] - 0s 9ms/step
# acc at 2541 epoch is: 0.9025
# 1/1 [==============================] - 0s 345ms/step - loss: 0.6530
# 13/13 [==============================] - 0s 7ms/step
# acc at 2542 epoch is: 0.9025
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6529
# 13/13 [==============================] - 0s 5ms/step
# acc at 2543 epoch is: 0.9025
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6529
# 13/13 [==============================] - 0s 5ms/step
# acc at 2544 epoch is: 0.9025
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6528
# 13/13 [==============================] - 0s 5ms/step
# acc at 2545 epoch is: 0.9025
# 1/1 [==============================] - 0s 183ms/step - loss: 0.6528
# 13/13 [==============================] - 0s 4ms/step
# acc at 2546 epoch is: 0.9025
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6527
# 13/13 [==============================] - 0s 4ms/step
# acc at 2547 epoch is: 0.9025
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6527
# 13/13 [==============================] - 0s 4ms/step
# acc at 2548 epoch is: 0.9025
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6527
# 13/13 [==============================] - 0s 5ms/step
# acc at 2549 epoch is: 0.9025
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6526
# 13/13 [==============================] - 0s 4ms/step
# acc at 2550 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6526
# 13/13 [==============================] - 0s 4ms/step
# acc at 2551 epoch is: 0.9025
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6525
# 13/13 [==============================] - 0s 4ms/step
# acc at 2552 epoch is: 0.9025
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6525
# 13/13 [==============================] - 0s 4ms/step
# acc at 2553 epoch is: 0.9025
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6524
# 13/13 [==============================] - 0s 6ms/step
# acc at 2554 epoch is: 0.9025
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6524
# 13/13 [==============================] - 0s 5ms/step
# acc at 2555 epoch is: 0.9025
# 1/1 [==============================] - 0s 223ms/step - loss: 0.6523
# 13/13 [==============================] - 0s 5ms/step
# acc at 2556 epoch is: 0.9025
# 1/1 [==============================] - 0s 232ms/step - loss: 0.6523
# 13/13 [==============================] - 0s 6ms/step
# acc at 2557 epoch is: 0.9025
# 1/1 [==============================] - 1s 509ms/step - loss: 0.6522
# 13/13 [==============================] - 0s 9ms/step
# acc at 2558 epoch is: 0.9025
# 1/1 [==============================] - 0s 323ms/step - loss: 0.6522
# 13/13 [==============================] - 0s 8ms/step
# acc at 2559 epoch is: 0.9025
# 1/1 [==============================] - 0s 349ms/step - loss: 0.6521
# 13/13 [==============================] - 0s 5ms/step
# acc at 2560 epoch is: 0.9025
# 1/1 [==============================] - 0s 232ms/step - loss: 0.6521
# 13/13 [==============================] - 0s 4ms/step
# acc at 2561 epoch is: 0.9025
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6520
# 13/13 [==============================] - 0s 4ms/step
# acc at 2562 epoch is: 0.9025
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6520
# 13/13 [==============================] - 0s 4ms/step
# acc at 2563 epoch is: 0.9025
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6519
# 13/13 [==============================] - 0s 5ms/step
# acc at 2564 epoch is: 0.9025
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6519
# 13/13 [==============================] - 0s 4ms/step
# acc at 2565 epoch is: 0.9025
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6518
# 13/13 [==============================] - 0s 5ms/step
# acc at 2566 epoch is: 0.9025
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6518
# 13/13 [==============================] - 0s 6ms/step
# acc at 2567 epoch is: 0.9025
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6517
# 13/13 [==============================] - 0s 4ms/step
# acc at 2568 epoch is: 0.9025
# 1/1 [==============================] - 0s 237ms/step - loss: 0.6517
# 13/13 [==============================] - 0s 4ms/step
# acc at 2569 epoch is: 0.9025
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6516
# 13/13 [==============================] - 0s 5ms/step
# acc at 2570 epoch is: 0.9025
# ...
# acc at 3893 epoch is: 0.9025
# 1/1 [==============================] - 0s 295ms/step - loss: 0.5992
# 13/13 [==============================] - 0s 4ms/step
# acc at 3894 epoch is: 0.9025
# 1/1 [==============================] - 0s 217ms/step - loss: 0.5992
# 13/13 [==============================] - 0s 5ms/step
# acc at 3895 epoch is: 0.9025
# 1/1 [==============================] - 0s 196ms/step - loss: 0.
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5967
# 13/13 [==============================] - 0s 4ms/step
# acc at 3973 epoch is: 0.9025
# 1/1 [==============================] - 0s 291ms/step - loss: 0.5967
# 13/13 [==============================] - 0s 4ms/step
# acc at 3974 epoch is: 0.9025
# 1/1 [==============================] - 0s 296ms/step - loss: 0.5966
# 13/13 [==============================] - 0s 5ms/step
# acc at 3975 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.5966
# 13/13 [==============================] - 0s 5ms/step
# acc at 3976 epoch is: 0.9025
# 1/1 [==============================] - 0s 183ms/step - loss: 0.5966
# 13/13 [==============================] - 0s 4ms/step
# acc at 3977 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.5965
# 13/13 [==============================] - 0s 5ms/step
# acc at 3978 epoch is: 0.9025
# 1/1 [==============================] - 0s 286ms/step - loss: 0.5965
# 13/13 [==============================] - 0s 5ms/step
# acc at 3979 epoch is: 0.9025
# 1/1 [==============================] - 0s 257ms/step - loss: 0.5965
# 13/13 [==============================] - 0s 6ms/step
# acc at 3980 epoch is: 0.9025
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5964
# 13/13 [==============================] - 0s 4ms/step
# acc at 3981 epoch is: 0.9025
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5964
# 13/13 [==============================] - 0s 4ms/step
# acc at 3982 epoch is: 0.9025
# 1/1 [==============================] - 0s 190ms/step - loss: 0.5964
# 13/13 [==============================] - 0s 4ms/step
# acc at 3983 epoch is: 0.9025
# 1/1 [==============================] - 0s 299ms/step - loss: 0.5963
# 13/13 [==============================] - 0s 5ms/step
# acc at 3984 epoch is: 0.9025
# 1/1 [==============================] - 0s 193ms/step - loss: 0.5963
# 13/13 [==============================] - 0s 5ms/step
# acc at 3985 epoch is: 0.9025
# 1/1 [==============================] - 0s 326ms/step - loss: 0.5963
# 13/13 [==============================] - 0s 5ms/step
# acc at 3986 epoch is: 0.9025
# 1/1 [==============================] - 0s 382ms/step - loss: 0.5963
# 13/13 [==============================] - 0s 8ms/step
# acc at 3987 epoch is: 0.9025
# 1/1 [==============================] - 0s 314ms/step - loss: 0.5962
# 13/13 [==============================] - 0s 8ms/step
# acc at 3988 epoch is: 0.9025
# 1/1 [==============================] - 0s 216ms/step - loss: 0.5962
# 13/13 [==============================] - 0s 5ms/step
# acc at 3989 epoch is: 0.9025
# 1/1 [==============================] - 0s 191ms/step - loss: 0.5962
# 13/13 [==============================] - 0s 4ms/step
# acc at 3990 epoch is: 0.9025
# 1/1 [==============================] - 0s 212ms/step - loss: 0.5961
# 13/13 [==============================] - 0s 4ms/step
# acc at 3991 epoch is: 0.9025
# 1/1 [==============================] - 0s 200ms/step - loss: 0.5961
# 13/13 [==============================] - 0s 4ms/step
# acc at 3992 epoch is: 0.9025
# 1/1 [==============================] - 0s 200ms/step - loss: 0.5961
# 13/13 [==============================] - 0s 4ms/step
# acc at 3993 epoch is: 0.9025
# 1/1 [==============================] - 0s 191ms/step - loss: 0.5960
# 13/13 [==============================] - 0s 5ms/step
# acc at 3994 epoch is: 0.9025
# 1/1 [==============================] - 0s 199ms/step - loss: 0.5960
# 13/13 [==============================] - 0s 4ms/step
# acc at 3995 epoch is: 0.9025
# 1/1 [==============================] - 0s 227ms/step - loss: 0.5960
# 13/13 [==============================] - 0s 5ms/step
# acc at 3996 epoch is: 0.9025
# 1/1 [==============================] - 0s 194ms/step - loss: 0.5959
# 13/13 [==============================] - 0s 5ms/step
# acc at 3997 epoch is: 0.9025
# 1/1 [==============================] - 0s 186ms/step - loss: 0.5959
# 13/13 [==============================] - 0s 4ms/step
# acc at 3998 epoch is: 0.9025
# 1/1 [==============================] - 0s 290ms/step - loss: 0.5959
# 13/13 [==============================] - 0s 5ms/step
# acc at 3999 epoch is: 0.9025
# 0.9025 0.9426182097888282 0.9025 0.9137320318570318
